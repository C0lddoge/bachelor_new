# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('bmh')
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.size": 20,
    "axes.titlesize": 20,
    "axes.labelsize": 20,
    "font.sans-serif": ["Helvetica"],
    "axes.facecolor": '#ffffff',
    "figure.autolayout": True,
	})

# %%
def return_name(N,L):
    return 'SP_N{:},{:}_L{:}_f166,200_rdf_00.dat'.format(N[0],N[1],L)

# %%
N = [400,112]
Ls = [12.38,11.35]

# %%
for L in Ls:
    data = np.loadtxt('./data/' + return_name(N,L),delimiter = ';')
    plt.errorbar(data[:,0],data[:,1],yerr=data[:,2],label = '$\\rho = {:.2f}$'.format(np.sum(N)/L**3))
    plt.ylim(0,5)
    plt.xlabel('r')
    plt.ylabel('g(r)')
plt.legend()
plt.savefig('gr.pdf')
