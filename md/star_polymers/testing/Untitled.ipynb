# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('table.txt',skiprows = 5)

# %%
print(data)
# Out:
# [[1.00000000e+00 1.00000000e-02 2.81576228e+03 5.94100108e+04]
#  [2.00000000e+00 1.39879760e-02 2.61637456e+03 4.24721997e+04]
#  [3.00000000e+00 1.79759519e-02 2.46735241e+03 3.30497162e+04]
#  ...
#  [4.98000000e+02 1.99202405e+00 6.72110544e-02 4.66717012e-01]
#  [4.99000000e+02 1.99601202e+00 6.53754644e-02 4.53905010e-01]
#  [5.00000000e+02 2.00000000e+00 6.35902597e-02 4.41446722e-01]]

# %%
data = data[:,1:]

# %%
plt.plot(data[:,0],data[:,1])
plt.plot(data[:,0],data[:,2])
plt.yscale('log')
