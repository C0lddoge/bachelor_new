# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('bmh')
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.size": 20,
    "axes.titlesize": 20,
    "axes.labelsize": 20,
    "font.sans-serif": ["Helvetica"],
    "axes.facecolor": '#ffffff',
    "figure.autolayout": True,
	})

# %%
colors2 = {
   '0': 'darkred',
   '1': 'steelblue',
  '00': 'darkred',
  '10': 'rebeccapurple',
  '11': 'steelblue',
}

# %%
data_dir = './rdf_M100,25_k0,30/'
expo_dir = './export_rp/'

# %%
def return_name_md(N1, N2, L,types):
    return 'RP_N{:},{:}_L{:}_newpot_rdf_{:}{:}.dat'.format(N1,N2,L,*types)
def return_name_md2(N1, N2, L,types):
    return 'RP_N{:},{:}_L{:}_M100,25_k0,30_rdf_{:}{:}.dat'.format(N1,N2,L,*types)

# %%
Ns = [[1000,0],[1331,0],[1728,0],[0,1000],[0,1331],[0,1728],[500,500],[666,666],[864,864]]
Ns = [[500,500][666,666],[864,864]]
Ls = [99.99,58.48,43.68,41.98,41.61]
# Out:
# <>:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# /tmp/ipykernel_5810/2769747919.py:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   Ns = [[500,500][666,666],[864,864]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5810/2769747919.py in <module>
#       1 Ns = [[1000,0],[1331,0],[1728,0],[0,1000],[0,1331],[0,1728],[500,500],[666,666],[864,864]]
# ----> 2 Ns = [[500,500][666,666],[864,864]]
#       3 Ls = [99.99,58.48,43.68,41.98,41.61]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#fig,axs = plt.subplots(1,5,figsize = (25,5))
counter = 0
for nind,n in enumerate(Ns):
    #x,y = np.unravel_index(nind,(,3))
    for lind,L in enumerate(Ls):
        if os.path.exists(data_dir + return_name_md2(n[0],n[1],L,comb)):
            fig,axs = plt.subplots(figsize=(20,10))
            for c, comb in enumerate([[0,0], [1,0], [1,1]]):
                   # print(comb)
                   # print(f'n1: {n[0]};n2: {n[1]}')
                    data = np.loadtxt(data_dir + return_name_md2(n[0],n[1],L,comb),delimiter =';') 
                    axs.errorbar(data[:,0], data[:,1],yerr = data[:,2],marker = 'x',linewidth = 1.5,elinewidth = 1.5, label = 'CG; {:}{:}'.format(comb[1]+1,comb[0]+1),markersize= 5.0, color = colors2['{:}{:}'.format(*comb)])
                    axs.legend()
                    axs.set_xlabel('$r \ [\\sigma]$')
                    axs.set_ylabel('$g_{ij}(r)$')
                    #axs[x][y].set_yscale('log')
                    axs.set_ylim(0,5)
                    axs.set_title('N1 = {:} ; N2 = {:} ; L = {:}'.format(n[0],n[1],L))
            fig.savefig(expo_dir + 'gr_N{:},{:}_L{:}_M100,25_k0,30.pdf'.format(n[0],n[1],L))
            counter+=1
#fig.savefig(expo_dir + 'gr_M100,25_k0,30_highdens.pdf')
