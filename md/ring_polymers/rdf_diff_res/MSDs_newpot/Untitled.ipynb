# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = np.loadtxt('RP_N256,256_L44.03_newpot_MSDs_1_err.dat')
data2 = np.loadtxt('RP_N256,256_L44.03_newpot_MSDs_2_err.dat')
data3 = np.loadtxt('RP_N256,256_L80.0_newpot_MSDs_1_err.dat')
data4 = np.loadtxt('RP_N256,256_L80.0_newpot_MSDs_2_err.dat')

# %%
plt.errorbar(data1[:,0],data1[:,1],yerr=data1[:,3],label = '1 44')
plt.errorbar(data2[:,0],data2[:,1],yerr=data2[:,3], label = '2 44')
plt.errorbar(data3[:,0],data3[:,1],yerr=data3[:,3],label = '1 80')
plt.errorbar(data4[:,0],data4[:,1],yerr=data4[:,3],label='2 80')


plt.xscale('log')
plt.yscale('log')
plt.legend()
